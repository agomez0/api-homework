# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %% [markdown]
# # Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create dataframe and add cities 
weather_df = pd.DataFrame({"City": cities, "Cloudiness": "", "Country": "", "Date": "",
                           "Humidity": "", "Lat": "", "Lng": "", "Max Temp": "", "Wind Speed": ""})

print("Beginning Data Retrieval")
print("-----------------------------")

#initiate record and set counter
record_counter = 0
set_counter = 0

#loop through rows in the dataframe
for index, row in weather_df.iterrows():
    cit = row["City"]
    url = ('http://api.openweathermap.org/data/2.5/weather?q={0}&appid={1}&units=imperial').format(cit, api_key)
    data = requests.get(url).json()
    
    #reset record counter when it reaches 50
    #increase record counter by 1 after every row
    if (record_counter % 50 == 0):
        record_counter = 0
        set_counter += 1
        
    record_counter += 1
    
    #input values into dataframe
    try:
        weather_df.loc[index, "Cloudiness"] = data["clouds"]["all"]
        weather_df.loc[index, "Country"] = data["sys"]["country"]
        weather_df.loc[index, "Date"] = str(data["dt"])
        weather_df.loc[index, "Humidity"] = data["main"]["humidity"]
        weather_df.loc[index, "Lat"] = data["coord"]["lat"]
        weather_df.loc[index, "Lng"] = data["coord"]["lon"]
        weather_df.loc[index, "Max Temp"] = data["main"]["temp_max"]
        weather_df.loc[index, "Wind Speed"] = data["wind"]["speed"]
        
        print(f"Processing Record {record_counter} of Set {set_counter} | {cit}")
        
    except (KeyError, IndexError):
        print("City not found... skipping.")
        
print("-----------------------------")        
print("Data Retrieval Complete ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | touros
# Processing Record 2 of Set 1 | geraldton
# City not found... skipping.
# Processing Record 4 of Set 1 | hambantota
# City not found... skipping.
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | leningradskiy
# Processing Record 8 of Set 1 | hutchinson
# Processing Record 9 of Set 1 | klaksvik
# City not found... skipping.
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | ushuaia
# City not found... skipping.
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | deputatskiy
# Processing Record 17 of Set 1 | dovbysh
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | nyanza
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | sioux lookout
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | boende
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | mayo
# City not found... skipping.
# Processing Record 33 of Set 1 | fort morgan
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | daru
# Processing Record 38 of Set 1 | broome
# Processing Record 39 of Set 1 | taltal
# Processing Record 40 of Set 1 | mena
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | victoria
# Processing Record 43 of Set 1 | port elizabeth
# City not found... skipping.
# Processing Record 45 of Set 1 | crestview
# Processing Record 46 of Set 1 | palmer
# Processing Record 47 of Set 1 | yuanping
# City not found... skipping.
# Processing Record 49 of Set 1 | apiai
# Processing Record 50 of Set 1 | dharchula
# Processing Record 1 of Set 2 | puerto ayora
# City not found... skipping.
# Processing Record 3 of Set 2 | carutapera
# Processing Record 4 of Set 2 | provideniya
# City not found... skipping.
# Processing Record 6 of Set 2 | harlingen
# City not found... skipping.
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | thompson
# City not found... skipping.
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | terrell
# Processing Record 13 of Set 2 | madimba
# Processing Record 14 of Set 2 | wukari
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | vilcun
# Processing Record 18 of Set 2 | bam
# Processing Record 19 of Set 2 | clyde river
# City not found... skipping.
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | show low
# Processing Record 23 of Set 2 | tortoli
# City not found... skipping.
# Processing Record 25 of Set 2 | coquimbo
# Processing Record 26 of Set 2 | bubaque
# City not found... skipping.
# Processing Record 28 of Set 2 | bandarbeyla
# Processing Record 29 of Set 2 | waipawa
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | longyan
# Processing Record 32 of Set 2 | kuito
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | yulara
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | san policarpo
# Processing Record 37 of Set 2 | myingyan
# Processing Record 38 of Set 2 | biu
# Processing Record 39 of Set 2 | la ronge
# Processing Record 40 of Set 2 | olinda
# Processing Record 41 of Set 2 | isangel
# Processing Record 42 of Set 2 | hofn
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | makakilo city
# Processing Record 47 of Set 2 | jamestown
# City not found... skipping.
# Processing Record 49 of Set 2 | angoche
# Processing Record 50 of Set 2 | constitucion
# Processing Record 1 of Set 3 | hobyo
# Processing Record 2 of Set 3 | longyearbyen
# Processing Record 3 of Set 3 | ulaangom
# Processing Record 4 of Set 3 | hermanus
# Processing Record 5 of Set 3 | daura
# Processing Record 6 of Set 3 | sola
# Processing Record 7 of Set 3 | yeppoon
# Processing Record 8 of Set 3 | bambous virieux
# Processing Record 9 of Set 3 | tamano
# City not found... skipping.
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | providencia
# Processing Record 13 of Set 3 | dongsheng
# Processing Record 14 of Set 3 | tombouctou
# Processing Record 15 of Set 3 | yerkoy
# Processing Record 16 of Set 3 | igunga
# Processing Record 17 of Set 3 | muros
# Processing Record 18 of Set 3 | rio grande
# Processing Record 19 of Set 3 | cabedelo
# Processing Record 20 of Set 3 | sitka
# Processing Record 21 of Set 3 | macamic
# City not found... skipping.
# Processing Record 23 of Set 3 | vestmannaeyjar
# Processing Record 24 of Set 3 | gambo
# City not found... skipping.
# Processing Record 26 of Set 3 | yerbogachen
# Processing Record 27 of Set 3 | manzanillo
# Processing Record 28 of Set 3 | alta
# Processing Record 29 of Set 3 | machico
# Processing Record 30 of Set 3 | husavik
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | cape town
# City not found... skipping.
# City not found... skipping.
# Processing Record 35 of Set 3 | ixtapa
# Processing Record 36 of Set 3 | faanui
# City not found... skipping.
# Processing Record 38 of Set 3 | ginda
# Processing Record 39 of Set 3 | bahia blanca
# Processing Record 40 of Set 3 | noyabrsk
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | airai
# City not found... skipping.
# Processing Record 44 of Set 3 | guerrero negro
# Processing Record 45 of Set 3 | talcahuano
# City not found... skipping.
# Processing Record 47 of Set 3 | northam
# Processing Record 48 of Set 3 | rolla
# Processing Record 49 of Set 3 | lagoa vermelha
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | axim
# Processing Record 2 of Set 4 | pisco
# Processing Record 3 of Set 4 | te anau
# Processing Record 4 of Set 4 | cockburn town
# Processing Record 5 of Set 4 | kaliua
# City not found... skipping.
# Processing Record 7 of Set 4 | atasu
# City not found... skipping.
# Processing Record 9 of Set 4 | hilo
# Processing Record 10 of Set 4 | saint george
# Processing Record 11 of Set 4 | salalah
# Processing Record 12 of Set 4 | tuatapere
# Processing Record 13 of Set 4 | san cristobal
# Processing Record 14 of Set 4 | iqaluit
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | solwezi
# Processing Record 18 of Set 4 | suhbaatar
# Processing Record 19 of Set 4 | trairi
# Processing Record 20 of Set 4 | katsuura
# Processing Record 21 of Set 4 | norman wells
# Processing Record 22 of Set 4 | corod
# Processing Record 23 of Set 4 | gizo
# Processing Record 24 of Set 4 | muzhi
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | huarmey
# Processing Record 27 of Set 4 | nikolskoye
# Processing Record 28 of Set 4 | iquitos
# Processing Record 29 of Set 4 | fairbanks
# Processing Record 30 of Set 4 | butaritari
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | bonfim
# Processing Record 33 of Set 4 | mitsamiouli
# City not found... skipping.
# City not found... skipping.
# Processing Record 36 of Set 4 | harper
# Processing Record 37 of Set 4 | tuktoyaktuk
# Processing Record 38 of Set 4 | felipe carrillo puerto
# Processing Record 39 of Set 4 | christchurch
# Processing Record 40 of Set 4 | koygorodok
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | samfya
# City not found... skipping.
# Processing Record 44 of Set 4 | inhambane
# Processing Record 45 of Set 4 | camabatela
# Processing Record 46 of Set 4 | mount gambier
# Processing Record 47 of Set 4 | bireun
# Processing Record 48 of Set 4 | morondava
# Processing Record 49 of Set 4 | poum
# Processing Record 50 of Set 4 | marienburg
# Processing Record 1 of Set 5 | gouyave
# Processing Record 2 of Set 5 | dzemul
# Processing Record 3 of Set 5 | iaciara
# Processing Record 4 of Set 5 | sao filipe
# Processing Record 5 of Set 5 | imbituba
# Processing Record 6 of Set 5 | kerema
# Processing Record 7 of Set 5 | lagoa
# Processing Record 8 of Set 5 | castro
# Processing Record 9 of Set 5 | shingu
# Processing Record 10 of Set 5 | chapais
# Processing Record 11 of Set 5 | la tuque
# Processing Record 12 of Set 5 | erenhot
# Processing Record 13 of Set 5 | tura
# Processing Record 14 of Set 5 | margate
# Processing Record 15 of Set 5 | atar
# Processing Record 16 of Set 5 | sompeta
# Processing Record 17 of Set 5 | sovetskiy
# Processing Record 18 of Set 5 | warri
# Processing Record 19 of Set 5 | noumea
# Processing Record 20 of Set 5 | arraial do cabo
# Processing Record 21 of Set 5 | ostrovnoy
# Processing Record 22 of Set 5 | cidreira
# Processing Record 23 of Set 5 | moose jaw
# Processing Record 24 of Set 5 | brae
# Processing Record 25 of Set 5 | taonan
# City not found... skipping.
# Processing Record 27 of Set 5 | beringovskiy
# Processing Record 28 of Set 5 | trinidad
# Processing Record 29 of Set 5 | alofi
# Processing Record 30 of Set 5 | maniitsoq
# Processing Record 31 of Set 5 | mindelheim
# Processing Record 32 of Set 5 | sayyan
# Processing Record 33 of Set 5 | pak phanang
# Processing Record 34 of Set 5 | alice springs
# Processing Record 35 of Set 5 | san quintin
# City not found... skipping.
# City not found... skipping.
# Processing Record 38 of Set 5 | brewster
# Processing Record 39 of Set 5 | kaeo
# Processing Record 40 of Set 5 | anadyr
# Processing Record 41 of Set 5 | maningrida
# Processing Record 42 of Set 5 | chuy
# City not found... skipping.
# Processing Record 44 of Set 5 | sorong
# Processing Record 45 of Set 5 | marsa matruh
# Processing Record 46 of Set 5 | luderitz
# Processing Record 47 of Set 5 | carnarvon
# City not found... skipping.
# Processing Record 49 of Set 5 | coos bay
# Processing Record 50 of Set 5 | karakol
# Processing Record 1 of Set 6 | gat
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | mackay
# Processing Record 4 of Set 6 | koraput
# Processing Record 5 of Set 6 | ust-kut
# City not found... skipping.
# Processing Record 7 of Set 6 | sao felix do xingu
# Processing Record 8 of Set 6 | lasa
# Processing Record 9 of Set 6 | zonguldak
# Processing Record 10 of Set 6 | dauriya
# Processing Record 11 of Set 6 | westport
# Processing Record 12 of Set 6 | pevek
# Processing Record 13 of Set 6 | namibe
# Processing Record 14 of Set 6 | ancud
# Processing Record 15 of Set 6 | sabang
# Processing Record 16 of Set 6 | yanam
# Processing Record 17 of Set 6 | garowe
# Processing Record 18 of Set 6 | atambua
# Processing Record 19 of Set 6 | cochabamba
# Processing Record 20 of Set 6 | aykhal
# City not found... skipping.
# Processing Record 22 of Set 6 | pacific grove
# Processing Record 23 of Set 6 | praia da vitoria
# Processing Record 24 of Set 6 | qaanaaq
# Processing Record 25 of Set 6 | anju
# Processing Record 26 of Set 6 | santo antonio do ica
# Processing Record 27 of Set 6 | mandalgovi
# Processing Record 28 of Set 6 | port shepstone
# Processing Record 29 of Set 6 | okha
# Processing Record 30 of Set 6 | narsaq
# Processing Record 31 of Set 6 | itoman
# Processing Record 32 of Set 6 | port hardy
# Processing Record 33 of Set 6 | tongren
# Processing Record 34 of Set 6 | paamiut
# Processing Record 35 of Set 6 | hualmay
# Processing Record 36 of Set 6 | genoa
# Processing Record 37 of Set 6 | fort nelson
# Processing Record 38 of Set 6 | aklavik
# Processing Record 39 of Set 6 | lompoc
# City not found... skipping.
# Processing Record 41 of Set 6 | cherskiy
# Processing Record 42 of Set 6 | sheridan
# Processing Record 43 of Set 6 | arman
# Processing Record 44 of Set 6 | cabo san lucas
# Processing Record 45 of Set 6 | upernavik
# Processing Record 46 of Set 6 | biak
# Processing Record 47 of Set 6 | opuwo
# Processing Record 48 of Set 6 | andilamena
# Processing Record 49 of Set 6 | ahipara
# Processing Record 50 of Set 6 | xixiang
# Processing Record 1 of Set 7 | kamina
# Processing Record 2 of Set 7 | lavrentiya
# Processing Record 3 of Set 7 | teya
# Processing Record 4 of Set 7 | batagay
# Processing Record 5 of Set 7 | ponta do sol
# Processing Record 6 of Set 7 | dillon
# Processing Record 7 of Set 7 | bol
# Processing Record 8 of Set 7 | vangaindrano
# Processing Record 9 of Set 7 | kindu
# Processing Record 10 of Set 7 | at-bashi
# Processing Record 11 of Set 7 | marawi
# Processing Record 12 of Set 7 | hamilton
# City not found... skipping.
# Processing Record 14 of Set 7 | kinango
# Processing Record 15 of Set 7 | lancaster
# Processing Record 16 of Set 7 | koumac
# Processing Record 17 of Set 7 | sinop
# Processing Record 18 of Set 7 | antofagasta
# Processing Record 19 of Set 7 | ranau
# Processing Record 20 of Set 7 | paita
# Processing Record 21 of Set 7 | san luis
# City not found... skipping.
# Processing Record 23 of Set 7 | new norfolk
# Processing Record 24 of Set 7 | yelizovo
# Processing Record 25 of Set 7 | conde
# Processing Record 26 of Set 7 | portland
# Processing Record 27 of Set 7 | ambilobe
# Processing Record 28 of Set 7 | broken hill
# Processing Record 29 of Set 7 | rafraf
# Processing Record 30 of Set 7 | parabel
# Processing Record 31 of Set 7 | gamboula
# City not found... skipping.
# Processing Record 33 of Set 7 | bereda
# Processing Record 34 of Set 7 | zyryanka
# Processing Record 35 of Set 7 | yangambi
# Processing Record 36 of Set 7 | soure
# Processing Record 37 of Set 7 | gimli
# Processing Record 38 of Set 7 | moorhead
# City not found... skipping.
# Processing Record 40 of Set 7 | hilton head island
# Processing Record 41 of Set 7 | nemuro
# Processing Record 42 of Set 7 | mega
# Processing Record 43 of Set 7 | san patricio
# City not found... skipping.
# City not found... skipping.
# Processing Record 46 of Set 7 | necochea
# Processing Record 47 of Set 7 | camacha
# Processing Record 48 of Set 7 | sorland
# Processing Record 49 of Set 7 | amapa
# Processing Record 50 of Set 7 | burnie
# Processing Record 1 of Set 8 | uruzgan
# Processing Record 2 of Set 8 | malinovoye ozero
# Processing Record 3 of Set 8 | renqiu
# Processing Record 4 of Set 8 | mayakonda
# Processing Record 5 of Set 8 | baghdad
# Processing Record 6 of Set 8 | simpang
# Processing Record 7 of Set 8 | nalut
# City not found... skipping.
# Processing Record 9 of Set 8 | kalagarh
# Processing Record 10 of Set 8 | komsomolskiy
# Processing Record 11 of Set 8 | manacapuru
# Processing Record 12 of Set 8 | vila franca do campo
# City not found... skipping.
# City not found... skipping.
# Processing Record 15 of Set 8 | tilichiki
# Processing Record 16 of Set 8 | tarakan
# Processing Record 17 of Set 8 | alexandria
# Processing Record 18 of Set 8 | lardos
# Processing Record 19 of Set 8 | laguna
# Processing Record 20 of Set 8 | aswan
# Processing Record 21 of Set 8 | college
# Processing Record 22 of Set 8 | guanay
# Processing Record 23 of Set 8 | vitim
# City not found... skipping.
# Processing Record 25 of Set 8 | kendari
# Processing Record 26 of Set 8 | sinnamary
# Processing Record 27 of Set 8 | cayenne
# Processing Record 28 of Set 8 | progreso
# Processing Record 29 of Set 8 | samarai
# Processing Record 30 of Set 8 | kenai
# Processing Record 31 of Set 8 | bonavista
# Processing Record 32 of Set 8 | caraballeda
# Processing Record 33 of Set 8 | calatayud
# Processing Record 34 of Set 8 | talnakh
# City not found... skipping.
# Processing Record 36 of Set 8 | kaduqli
# Processing Record 37 of Set 8 | flin flon
# Processing Record 38 of Set 8 | tadine
# Processing Record 39 of Set 8 | trelew
# Processing Record 40 of Set 8 | villa carlos paz
# Processing Record 41 of Set 8 | pyu
# Processing Record 42 of Set 8 | curuca
# Processing Record 43 of Set 8 | tocopilla
# Processing Record 44 of Set 8 | kawalu
# Processing Record 45 of Set 8 | vao
# Processing Record 46 of Set 8 | saldanha
# Processing Record 47 of Set 8 | hay river
# Processing Record 48 of Set 8 | los llanos de aridane
# Processing Record 49 of Set 8 | tayu
# Processing Record 50 of Set 8 | itarema
# Processing Record 1 of Set 9 | kommunisticheskiy
# Processing Record 2 of Set 9 | peskovka
# Processing Record 3 of Set 9 | nurota
# Processing Record 4 of Set 9 | tsiroanomandidy
# Processing Record 5 of Set 9 | eureka
# Processing Record 6 of Set 9 | sokoto
# Processing Record 7 of Set 9 | port antonio
# City not found... skipping.
# Processing Record 9 of Set 9 | glenwood springs
# Processing Record 10 of Set 9 | bratsk
# Processing Record 11 of Set 9 | mayya
# Processing Record 12 of Set 9 | derzhavinsk
# Processing Record 13 of Set 9 | jilin
# Processing Record 14 of Set 9 | ilebo
# City not found... skipping.
# Processing Record 16 of Set 9 | seoul
# City not found... skipping.
# Processing Record 18 of Set 9 | aktanysh
# Processing Record 19 of Set 9 | damaturu
# Processing Record 20 of Set 9 | usinsk
# Processing Record 21 of Set 9 | winnemucca
# Processing Record 22 of Set 9 | reftinskiy
# Processing Record 23 of Set 9 | dingle
# Processing Record 24 of Set 9 | igarka
# Processing Record 25 of Set 9 | praia
# Processing Record 26 of Set 9 | sumbe
# Processing Record 27 of Set 9 | beeville
# Processing Record 28 of Set 9 | slobidka
# Processing Record 29 of Set 9 | elko
# Processing Record 30 of Set 9 | mount isa
# Processing Record 31 of Set 9 | marquette
# City not found... skipping.
# Processing Record 33 of Set 9 | tshikapa
# Processing Record 34 of Set 9 | ibotirama
# Processing Record 35 of Set 9 | port-gentil
# Processing Record 36 of Set 9 | nome
# Processing Record 37 of Set 9 | santa rosa
# Processing Record 38 of Set 9 | dicabisagan
# Processing Record 39 of Set 9 | la rioja
# Processing Record 40 of Set 9 | shetpe
# Processing Record 41 of Set 9 | kurchum
# Processing Record 42 of Set 9 | shirokiy
# Processing Record 43 of Set 9 | bukama
# Processing Record 44 of Set 9 | kefamenanu
# Processing Record 45 of Set 9 | ballina
# City not found... skipping.
# Processing Record 47 of Set 9 | yokadouma
# Processing Record 48 of Set 9 | jutai
# Processing Record 49 of Set 9 | kahului
# Processing Record 50 of Set 9 | naze
# Processing Record 1 of Set 10 | kruisfontein
# Processing Record 2 of Set 10 | mahibadhoo
# Processing Record 3 of Set 10 | lorengau
# Processing Record 4 of Set 10 | kavieng
# Processing Record 5 of Set 10 | whitehorse
# Processing Record 6 of Set 10 | lujiang
# Processing Record 7 of Set 10 | madang
# City not found... skipping.
# Processing Record 9 of Set 10 | wana
# Processing Record 10 of Set 10 | taksimo
# Processing Record 11 of Set 10 | oussouye
# City not found... skipping.
# Processing Record 13 of Set 10 | matamoros
# Processing Record 14 of Set 10 | najran
# Processing Record 15 of Set 10 | saint-augustin
# Processing Record 16 of Set 10 | vila do maio
# Processing Record 17 of Set 10 | athabasca
# Processing Record 18 of Set 10 | dunedin
# Processing Record 19 of Set 10 | vardo
# Processing Record 20 of Set 10 | santa maria del oro
# City not found... skipping.
# Processing Record 22 of Set 10 | machalpur
# Processing Record 23 of Set 10 | grindavik
# Processing Record 24 of Set 10 | boshan
# Processing Record 25 of Set 10 | turgenevo
# City not found... skipping.
# Processing Record 27 of Set 10 | tecoanapa
# Processing Record 28 of Set 10 | salinopolis
# Processing Record 29 of Set 10 | ust-koksa
# Processing Record 30 of Set 10 | caiaponia
# Processing Record 31 of Set 10 | honiara
# Processing Record 32 of Set 10 | chengde
# Processing Record 33 of Set 10 | coihaique
# Processing Record 34 of Set 10 | bonthe
# Processing Record 35 of Set 10 | okhotsk
# Processing Record 36 of Set 10 | birjand
# Processing Record 37 of Set 10 | wawa
# Processing Record 38 of Set 10 | fortuna
# Processing Record 39 of Set 10 | codrington
# Processing Record 40 of Set 10 | yilan
# Processing Record 41 of Set 10 | nuuk
# City not found... skipping.
# Processing Record 43 of Set 10 | puerto asis
# Processing Record 44 of Set 10 | muravlenko
# Processing Record 45 of Set 10 | vung tau
# Processing Record 46 of Set 10 | talaja
# Processing Record 47 of Set 10 | half moon bay
# Processing Record 48 of Set 10 | ossora
# Processing Record 49 of Set 10 | teguldet
# Processing Record 50 of Set 10 | pottsville
# Processing Record 1 of Set 11 | kollegal
# Processing Record 2 of Set 11 | lata
# Processing Record 3 of Set 11 | kavaratti
# Processing Record 4 of Set 11 | sangar
# Processing Record 5 of Set 11 | chara
# Processing Record 6 of Set 11 | flinders
# Processing Record 7 of Set 11 | yuyao
# Processing Record 8 of Set 11 | karachi
# Processing Record 9 of Set 11 | solnechnyy
# Processing Record 10 of Set 11 | abu samrah
# Processing Record 11 of Set 11 | beloha
# City not found... skipping.
# Processing Record 13 of Set 11 | innisfail
# Processing Record 14 of Set 11 | puerto leguizamo
# Processing Record 15 of Set 11 | crixas
# Processing Record 16 of Set 11 | daokou
# Processing Record 17 of Set 11 | port blair
# Processing Record 18 of Set 11 | lubao
# Processing Record 19 of Set 11 | west plains
# Processing Record 20 of Set 11 | orbetello
# Processing Record 21 of Set 11 | richards bay
# Processing Record 22 of Set 11 | auki
# City not found... skipping.
# Processing Record 24 of Set 11 | piet retief
# Processing Record 25 of Set 11 | kokopo
# Processing Record 26 of Set 11 | skjervoy
# Processing Record 27 of Set 11 | salina
# Processing Record 28 of Set 11 | gigmoto
# Processing Record 29 of Set 11 | adrar
# Processing Record 30 of Set 11 | almeirim
# Processing Record 31 of Set 11 | dinskaya
# Processing Record 32 of Set 11 | caxito
# Processing Record 33 of Set 11 | mecca
# City not found... skipping.
# City not found... skipping.
# Processing Record 36 of Set 11 | wyndham
# Processing Record 37 of Set 11 | taoudenni
# Processing Record 38 of Set 11 | quilmana
# Processing Record 39 of Set 11 | caleta de carquin
# Processing Record 40 of Set 11 | cururupu
# Processing Record 41 of Set 11 | dawlatabad
# Processing Record 42 of Set 11 | sisimiut
# Processing Record 43 of Set 11 | rabo de peixe
# City not found... skipping.
# City not found... skipping.
# Processing Record 46 of Set 11 | prachuap khiri khan
# Processing Record 47 of Set 11 | townsville
# Processing Record 48 of Set 11 | yarim
# Processing Record 49 of Set 11 | prince rupert
# Processing Record 50 of Set 11 | nara
# Processing Record 1 of Set 12 | riyadh
# City not found... skipping.
# Processing Record 3 of Set 12 | raahe
# Processing Record 4 of Set 12 | vanavara
# City not found... skipping.
# Processing Record 6 of Set 12 | laem sing
# Processing Record 7 of Set 12 | bang mun nak
# Processing Record 8 of Set 12 | ushtobe
# Processing Record 9 of Set 12 | strezhevoy
# Processing Record 10 of Set 12 | pingliang
# City not found... skipping.
# Processing Record 12 of Set 12 | fray bentos
# Processing Record 13 of Set 12 | surt
# City not found... skipping.
# Processing Record 15 of Set 12 | wanaka
# City not found... skipping.
# Processing Record 17 of Set 12 | vila velha
# Processing Record 18 of Set 12 | pingshan
# City not found... skipping.
# Processing Record 20 of Set 12 | barabinsk
# Processing Record 21 of Set 12 | lom sak
# Processing Record 22 of Set 12 | china
# Processing Record 23 of Set 12 | iroquois falls
# Processing Record 24 of Set 12 | kingaroy
# Processing Record 25 of Set 12 | mugur-aksy
# Processing Record 26 of Set 12 | kuryk
# City not found... skipping.
# Processing Record 28 of Set 12 | cooma
# Processing Record 29 of Set 12 | tabas
# Processing Record 30 of Set 12 | viedma
# Processing Record 31 of Set 12 | langsa
# Processing Record 32 of Set 12 | gilgit
# Processing Record 33 of Set 12 | mokhsogollokh
# Processing Record 34 of Set 12 | kysyl-syr
# Processing Record 35 of Set 12 | khandyga
# Processing Record 36 of Set 12 | palora
# Processing Record 37 of Set 12 | zhezkazgan
# Processing Record 38 of Set 12 | vila
# City not found... skipping.
# Processing Record 40 of Set 12 | port lincoln
# Processing Record 41 of Set 12 | ibimirim
# Processing Record 42 of Set 12 | wanning
# Processing Record 43 of Set 12 | henties bay
# Processing Record 44 of Set 12 | pangody
# Processing Record 45 of Set 12 | byron bay
# Processing Record 46 of Set 12 | arkhipo-osipovka
# Processing Record 47 of Set 12 | clovis
# Processing Record 48 of Set 12 | fare
# Processing Record 49 of Set 12 | isiro
# Processing Record 50 of Set 12 | udachnyy
# Processing Record 1 of Set 13 | new bedford
# Processing Record 2 of Set 13 | singaparna
# Processing Record 3 of Set 13 | rawson
# Processing Record 4 of Set 13 | port hedland
# Processing Record 5 of Set 13 | batsfjord
# Processing Record 6 of Set 13 | micheweni
# Processing Record 7 of Set 13 | rocha
# Processing Record 8 of Set 13 | birobidzhan
# Processing Record 9 of Set 13 | marsh harbour
# City not found... skipping.
# Processing Record 11 of Set 13 | cassilandia
# Processing Record 12 of Set 13 | qaqortoq
# Processing Record 13 of Set 13 | acapulco
# Processing Record 14 of Set 13 | nhulunbuy
# Processing Record 15 of Set 13 | pavlodar
# Processing Record 16 of Set 13 | sorgun
# City not found... skipping.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#remove empty rows
new_weather = weather_df.replace("", np.nan)
new_weather = new_weather.dropna()

#save data to csv file
new_weather.to_csv(output_data_file)
new_weather
# Out:
#                  City  Cloudiness Country        Date  Humidity    Lat  \
# 0              touros        75.0      BR  1550959200      94.0  -5.20
# 1           geraldton        90.0      CA  1550960160      92.0  49.72
# 3          hambantota        40.0      LK  1550956200     100.0   6.12
# 5              avarua        76.0      CK  1550959200      70.0 -21.21
# 6       leningradskiy        80.0      RU  1550961893      97.0  69.38
# 7          hutchinson        90.0      US  1550959980      83.0  38.06
# 8            klaksvik         0.0      FO  1550960400      65.0  62.23
# 10            rikitea        92.0      PF  1550961894     100.0 -23.12
# 11            ushuaia        75.0      AR  1550959200      64.0 -54.81
# 13              bluff        36.0      AU  1550961895      56.0 -23.58
# 14             albany        75.0      US  1550958840      47.0  42.65
# 15        deputatskiy         0.0      RU  1550961673       0.0  69.30
# 16            dovbysh        88.0      UA  1550961896      68.0  50.37
# 17     severo-kurilsk        64.0      RU  1550961857     100.0  50.68
# 18          mahebourg         0.0      MU  1550961710      93.0 -20.41
# 19            mataura        76.0      NZ  1550961896      63.0 -46.19
# 20             nyanza        24.0      RW  1550961897      92.0  -2.35
# 21      mar del plata        80.0      AR  1550961897      48.0 -46.43
# 22     saint-philippe         1.0      CA  1550959200      54.0  45.36
# 23        east london        48.0      ZA  1550961898     100.0 -33.02
# 24      sioux lookout        90.0      CA  1550959380      92.0  50.10
# 25     ribeira grande        40.0      PT  1550959200      71.0  38.52
# 26             boende        32.0      CD  1550961898      93.0  -0.28
# 27             barrow         0.0      AR  1550961899      61.0 -38.31
# 28           tasiilaq         8.0      GL  1550958600      84.0  65.61
# 29       punta arenas        75.0      CL  1550959200      42.0 -53.16
# 30               mayo        20.0      CA  1550959200      63.0  63.59
# 32        fort morgan         0.0      US  1550959800      47.0  40.25
# 33         kaitangata        92.0      NZ  1550961900      74.0 -46.28
# 34             hobart         0.0      AU  1550959200      66.0 -42.88
# ..                ...         ...     ...         ...       ...    ...
# 584          khandyga         0.0      RU  1550962060      60.0  62.65
# 585            palora        40.0      EC  1550959200      61.0  -1.70
# 586        zhezkazgan        88.0      KZ  1550962061      69.0  47.80
# 587              vila        75.0      IT  1550958900      69.0  45.18
# 589      port lincoln         0.0      AU  1550962062      67.0 -34.72
# 590          ibimirim        64.0      BR  1550962062      95.0  -8.54
# 591           wanning         0.0      AT  1550960400      63.0  48.64
# 592       henties bay        32.0      NA  1550962062      97.0 -22.12
# 593           pangody        68.0      RU  1550962063      62.0  65.85
# 594         byron bay        75.0      AU  1550960940      94.0 -28.65
# 595  arkhipo-osipovka        64.0      RU  1550962063     100.0  44.37
# 596            clovis         1.0      US  1550961300      47.0  36.83
# 597              fare        44.0      PF  1550962064      98.0 -16.70
# 598             isiro        80.0      CD  1550962002      93.0   2.77
# 599          udachnyy        48.0      RU  1550962064      80.0  66.42
# 600       new bedford         1.0      US  1550961300      74.0  41.64
# 601        singaparna        56.0      ID  1550962065      94.0  -7.35
# 602            rawson         0.0      AR  1550962065      22.0 -43.30
# 603      port hedland         0.0      AU  1550959200      88.0 -20.31
# 604         batsfjord        88.0      NO  1550962066      94.0  70.63
# 605         micheweni        76.0      TZ  1550962066     100.0  -4.97
# 606             rocha        92.0      UY  1550962066      95.0 -34.48
# 607       birobidzhan         0.0      RU  1550962067      77.0  48.79
# 608     marsh harbour         8.0      BS  1550962067     100.0  26.54
# 610       cassilandia        44.0      BR  1550962067      91.0 -19.11
# 611          qaqortoq        20.0      GL  1550958600      43.0  60.72
# 612          acapulco        20.0      MX  1550958540      74.0  16.86
# 613         nhulunbuy         0.0      AU  1550959200      88.0 -12.18
# 614          pavlodar         0.0      KZ  1550959200      84.0  52.28
# 615            sorgun        68.0      TR  1550961997      85.0  39.81
#
#         Lng  Max Temp  Wind Speed
# 0    -35.46     78.80        3.36
# 1    -86.95     26.60        4.70
# 3     81.12     69.80        1.12
# 5   -159.78     84.20       11.41
# 6    178.42     -5.64        5.95
# 7    -97.93     37.40       27.51
# 8     -6.59     44.60       16.11
# 10  -134.97     80.72       10.76
# 11   -68.31     39.20       16.11
# 13   149.07     81.94        6.17
# 14   -73.75     37.40        3.36
# 15   139.90    -45.87        2.71
# 16    27.99     23.21        6.51
# 17   156.12     22.18       14.34
# 18    57.70     76.09        3.83
# 19   168.86     55.21       13.78
# 20    29.75     56.78        2.82
# 21   -67.52     57.77       16.46
# 22   -73.48     32.00        6.93
# 23    27.91     73.07       12.66
# 24   -91.92     26.60        4.70
# 25   -28.70     57.20       19.46
# 26    20.88     72.62        2.15
# 27   -60.23     63.49       14.90
# 28   -37.64     32.00       14.99
# 29   -70.91     46.40       17.22
# 30  -135.90     -5.81        3.36
# 32  -103.80     33.80       21.92
# 33   169.85     51.70       14.79
# 34   147.33     55.40        9.17
# ..      ...       ...         ...
# 584  135.58    -34.08        2.59
# 585  -77.97     82.40        2.24
# 586   67.71     10.75        2.93
# 587    8.40     42.80        4.70
# 589  135.86     77.08       12.21
# 590  -37.69     70.73        2.37
# 591   13.53     26.60        5.82
# 592   14.28     66.77        4.61
# 593   74.49    -13.92        3.38
# 594  153.62     73.40       12.75
# 595   38.53     33.11       10.65
# 596 -119.70     57.20        3.83
# 597 -151.02     83.74       14.00
# 598   27.62     68.71        2.93
# 599  112.40      2.60        4.27
# 600  -70.93     39.20        3.36
# 601  108.11     69.65        1.25
# 602  -65.11     58.18       15.23
# 603  118.58     80.60        4.72
# 604   29.72     39.23       15.35
# 605   39.83     78.92        6.73
# 606  -54.34     70.78        4.38
# 607  132.93     29.74       10.76
# 608  -77.06     75.64       14.34
# 610  -51.73     75.01        1.14
# 611  -46.03     14.00       12.75
# 612  -99.88     82.40        9.17
# 613  136.78     82.40        4.70
# 614   76.96      1.40        6.71
# 615   35.19     30.77        1.59
#
# [544 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(new_weather["Lat"], new_weather["Max Temp"], edgecolors="black")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Max Temperature (date)")
plt.grid()
plt.savefig("images/latvstemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(new_weather["Lat"], new_weather["Humidity"], edgecolors="black")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Humidity")
plt.grid()
plt.ylim(top = 110)
plt.savefig("images/latvshumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(new_weather["Lat"], new_weather["Cloudiness"], edgecolors="black")
plt.ylabel("Cloudiness %")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Cloudiness")
plt.grid()
plt.savefig("images/latvscloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(new_weather["Lat"], new_weather["Wind Speed"], edgecolors="black")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Wind Speed")
plt.grid()
plt.savefig("images/latvswindspeed.png")
plt.show()
